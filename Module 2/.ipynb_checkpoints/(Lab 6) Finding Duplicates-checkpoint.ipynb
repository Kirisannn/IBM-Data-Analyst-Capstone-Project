# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %% [raw]
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
import requests
from tqdm.notebook import tqdm
from urllib.parse import urlparse

# %%
# Set URL & parse filename
dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
# Parse the URL
data_name = urlparse(dataset_url).path.strip('/').split('/')[-1]

# %%
# Download if necessary
r = requests.get(dataset_url, stream=True)
total_size = int(r.headers.get('content-length', 0))  # in bytes
chunk_size = 1024  # 1 KB

with open(data_name, 'wb') as file, tqdm(
    desc=f"Downloading {data_name}",
    total=total_size,
    unit='B',
    unit_scale=True,
    unit_divisor=1024,
) as bar:
    for chunk in r.iter_content(chunk_size=chunk_size):
        if chunk:  # filter out keep-alive chunks
            file.write(chunk)
            bar.update(len(chunk))
# Out:
# Downloading survey-data-with-duplicate.csv:   0%|          | 0.00/148M [00:00<?, ?B/s]

# %%
# Read data
df = pd.read_csv(data_name)

# Display the first few rows
df.head(n=3)
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
#
#                                            EdLevel  \
# 0                        Primary/elementary school
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
#
# [3 rows x 114 columns]

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
duplicates = df[df.duplicated(keep=False)]
print("Number of duplicates:", duplicates.shape[0])
# Out:
# Number of duplicates: 40

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
duplicates2 = df[df.duplicated(keep=False, subset=['MainBranch', 'Employment', 'RemoteWork'])]

# %%
dup2_grouped = duplicates2.groupby(['MainBranch', 'Employment', 'RemoteWork'])

# %%
pd.set_option('display.max_rows', None)

# %%
# Calculate proportion of identical values for each column in each group
identical_counts = {}
for col in df.columns:
    if col not in ['MainBranch', 'Employment', 'RemoteWork']:
        identical_counts[col] = dup2_grouped[col].nunique().eq(1).mean()

# Sort to see which columns are most frequently identical
identical_summary = pd.Series(identical_counts).sort_values(ascending=False)
print(identical_summary)
# Out:
# Check                             1.000000
# ICorPM                            0.304075
# AIThreat                          0.275862
# SOAccount                         0.266458
# AINextLess integrated             0.238245
# SurveyLength                      0.235110
# AISelect                          0.235110
# AINextMuch more integrated        0.231975
# SOPartFreq                        0.210031
# AINextNo change                   0.210031
# AIToolNot interested in Using     0.210031
# AIComplex                         0.200627
# MiscTechAdmired                   0.191223
# PlatformWantToWorkWith            0.191223
# EmbeddedWantToWorkWith            0.188088
# AISent                            0.184953
# PlatformAdmired                   0.184953
# ProfessionalCloud                 0.181818
# SurveyEase                        0.181818
# ProfessionalQuestion              0.181818
# Frequency_1                       0.181818
# TechDoc                           0.181818
# EmbeddedHaveWorkedWith            0.181818
# EmbeddedAdmired                   0.181818
# Knowledge_3                       0.178683
# JobSatPoints_11                   0.175549
# TBranch                           0.175549
# AINextMore integrated             0.175549
# Knowledge_1                       0.172414
# JobSatPoints_4                    0.172414
# Industry                          0.169279
# TimeAnswering                     0.169279
# Knowledge_5                       0.169279
# AIAcc                             0.169279
# Knowledge_6                       0.169279
# JobSatPoints_1                    0.166144
# AINextMuch less integrated        0.166144
# Knowledge_8                       0.166144
# Frequency_2                       0.166144
# JobSatPoints_10                   0.163009
# OfficeStackAsyncWantToWorkWith    0.163009
# MiscTechWantToWorkWith            0.163009
# PlatformHaveWorkedWith            0.159875
# Knowledge_7                       0.159875
# Knowledge_4                       0.159875
# Knowledge_2                       0.159875
# OfficeStackAsyncAdmired           0.159875
# Knowledge_9                       0.159875
# JobSatPoints_5                    0.156740
# Frequency_3                       0.156740
# TimeSearching                     0.153605
# JobSatPoints_9                    0.153605
# JobSatPoints_8                    0.150470
# AIChallenges                      0.150470
# WebframeAdmired                   0.150470
# JobSatPoints_6                    0.144201
# JobSatPoints_7                    0.144201
# MiscTechHaveWorkedWith            0.144201
# JobSat                            0.141066
# AIToolInterested in Using         0.137931
# WebframeWantToWorkWith            0.137931
# Frustration                       0.137931
# ToolsTechWantToWorkWith           0.131661
# ProfessionalTech                  0.131661
# WorkExp                           0.131661
# DatabaseWantToWorkWith            0.131661
# DatabaseAdmired                   0.128527
# ToolsTechAdmired                  0.128527
# AIToolCurrently Using             0.125392
# AISearchDevAdmired                0.122257
# AISearchDevWantToWorkWith         0.122257
# NEWCollabToolsAdmired             0.122257
# OfficeStackAsyncHaveWorkedWith    0.122257
# AIBen                             0.119122
# WebframeHaveWorkedWith            0.115987
# NEWCollabToolsWantToWorkWith      0.112853
# DatabaseHaveWorkedWith            0.112853
# OfficeStackSyncAdmired            0.112853
# NEWSOSites                        0.112853
# OfficeStackSyncWantToWorkWith     0.109718
# ConvertedCompYearly               0.109718
# AIEthics                          0.106583
# CompTotal                         0.106583
# OpSysProfessional use             0.106583
# LearnCodeOnline                   0.103448
# SOVisitFreq                       0.100313
# AISearchDevHaveWorkedWith         0.100313
# BuildvsBuy                        0.097179
# SOComm                            0.097179
# LanguageAdmired                   0.097179
# ToolsTechHaveWorkedWith           0.094044
# Age                               0.094044
# PurchaseInfluence                 0.087774
# OfficeStackSyncHaveWorkedWith     0.078370
# EdLevel                           0.072100
# OpSysPersonal use                 0.068966
# NEWCollabToolsHaveWorkedWith      0.068966
# LanguageWantToWorkWith            0.068966
# OrgSize                           0.062696
# SOHow                             0.062696
# Country                           0.059561
# DevType                           0.056426
# LanguageHaveWorkedWith            0.043887
# YearsCode                         0.040752
# LearnCode                         0.037618
# Currency                          0.031348
# YearsCodePro                      0.025078
# TechEndorse                       0.025078
# BuyNewTool                        0.021944
# CodingActivities                  0.003135
# ResponseId                        0.000000
# dtype: float64

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
# Get counts for 'Country' and 'Employment'
country_dups = duplicates2['Country'].value_counts()
employment_dups = duplicates2['Employment'].value_counts()

# %%
import seaborn as sns

top_employments = pd.DataFrame(employment_dups.head(10)).reset_index()
top_employments['Percentage (%)'] = top_employments['count'] / top_employments['count'].sum() * 100 

plt.figure(figsize=(8,6))
sns.barplot(data=top_employments, hue='Employment', y='Percentage (%)', palette='muted', gap=0.1)
plt.xlim(-0.41, 0.41)
plt.legend(title='Type of Employment', bbox_to_anchor=(1,0.75))
plt.show()

# %%
top_employments = pd.DataFrame(employment_dups.head(10)).reset_index()
top_employments['Percentage'] = top_employments['count'] / top_employments['count'].sum() * 100 

plt.figure(figsize=(8,6))
plt.pie(data=top_employments, x='count', autopct='%1.1f%%', startangle=180, pctdistance=1.15)
plt.legend(top_employments['Employment'], title='Employment Types', bbox_to_anchor=(1,0.8))
plt.show()

# %%
top_countries
# Out:
#                                                     count
# Country
# United States of America                            11065
# Germany                                              4946
# India                                                4222
# United Kingdom of Great Britain and Northern Ir...   3224
# Ukraine                                              2664
# France                                               2109
# Canada                                               2101
# Poland                                               1531
# Netherlands                                          1448
# Brazil                                               1372

# %%
top_countries = pd.DataFrame(country_dups.head(10)).reset_index()

plt.figure(figsize=(8,6))
plt.pie(data=top_countries, x='count', autopct='%1.1f%%', pctdistance=1.15)
plt.legend(top_countries['Country'], title='Countries', bbox_to_anchor=(1,0.8))
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
