# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Missing Values**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# Data wrangling is the process of cleaning, transforming, and organizing data to make it suitable for analysis. Finding and handling missing values is a crucial step in this process to ensure data accuracy and completeness. In this lab, you will focus exclusively on identifying and handling missing values in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# -   Identify missing values in the dataset.
#
# - Quantify missing values for specific columns.
#
# - Impute missing values using various strategies.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# ##### Setup: Install Required Libraries

# %% [raw]
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ##### Import Necessary Modules:

# %%
# Data processing libraries
import pandas as pd
import numpy as np

# Plotting libraries
import matplotlib as plt
import seaborn as sns

# For downloading
import requests
from tqdm.notebook import tqdm
from urllib.parse import urlparse

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Tasks

# %% [markdown]
# <h2>1. Load the Dataset</h2>
# <p>
# We use the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
data_name = urlparse(dataset_url).path.strip('/').split('/')[-1]

# %% [raw]
# # Download if necessary
# r = requests.get(dataset_url, stream=True)
# total_size = int(r.headers.get('content-length', 0))  # in bytes
# chunk_size = 1024  # 1 KB
#
# with open(data_name, 'wb') as file, tqdm(
#     desc=f"Downloading {data_name}",
#     total=total_size,
#     unit='B',
#     unit_scale=True,
#     unit_divisor=1024,
# ) as bar:
#     for chunk in r.iter_content(chunk_size=chunk_size):
#         if chunk:  # filter out keep-alive chunks
#             file.write(chunk)
#             bar.update(len(chunk))

# %%
# Read data and display
df = pd.read_csv(data_name)
df.head(n=3)
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
#
#                                            EdLevel  \
# 0                        Primary/elementary school
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
#
#                                      LearnCodeOnline  \
# 0                                                NaN
# 1  Technical documentation;Blogs;Books;Written Tu...
# 2  Technical documentation;Blogs;Books;Written Tu...
#
#                                              TechDoc YearsCode YearsCodePro  \
# 0                                                NaN       NaN          NaN
# 1  API document(s) and/or SDK document(s);User gu...        20           17
# 2  API document(s) and/or SDK document(s);User gu...        37           27
#
#                  DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy  \
# 0                    NaN     NaN               NaN        NaN        NaN
# 1  Developer, full-stack     NaN               NaN        NaN        NaN
# 2   Developer Experience     NaN               NaN        NaN        NaN
#
#   TechEndorse                                            Country Currency  \
# 0         NaN                           United States of America      NaN
# 1         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 2         NaN  United Kingdom of Great Britain and Northern I...      NaN
#
#    CompTotal                             LanguageHaveWorkedWith  \
# 0        NaN                                                NaN
# 1        NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2        NaN                                                 C#
#
#                               LanguageWantToWorkWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
#
#                                      LanguageAdmired  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
#
#         DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                          NaN                         NaN
# 1  Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2   Firebase Realtime Database  Firebase Realtime Database
#
#               DatabaseAdmired                    PlatformHaveWorkedWith  \
# 0                         NaN                                       NaN
# 1                  PostgreSQL  Amazon Web Services (AWS);Heroku;Netlify
# 2  Firebase Realtime Database                              Google Cloud
#
#                      PlatformWantToWorkWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
#
#                             PlatformAdmired         WebframeHaveWorkedWith  \
# 0                                       NaN                            NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify  Express;Next.js;Node.js;React
# 2                              Google Cloud                   ASP.NET CORE
#
#              WebframeWantToWorkWith        WebframeAdmired  \
# 0                               NaN                    NaN
# 1  Express;Htmx;Node.js;React;Remix  Express;Node.js;React
# 2                      ASP.NET CORE           ASP.NET CORE
#
#   EmbeddedHaveWorkedWith EmbeddedWantToWorkWith EmbeddedAdmired  \
# 0                    NaN                    NaN             NaN
# 1                    NaN                    NaN             NaN
# 2            Rasberry Pi            Rasberry Pi     Rasberry Pi
#
#                             MiscTechHaveWorkedWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
#
#                             MiscTechWantToWorkWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
#
#                                    MiscTechAdmired  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
#
#                        ToolsTechWantToWorkWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
#
#                               ToolsTechAdmired  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
#
#           NEWCollabToolsHaveWorkedWith         NEWCollabToolsWantToWorkWith  \
# 0                                  NaN                                  NaN
# 1  PyCharm;Visual Studio Code;WebStorm  PyCharm;Visual Studio Code;WebStorm
# 2                        Visual Studio                        Visual Studio
#
#                  NEWCollabToolsAdmired OpSysPersonal use  \
# 0                                  NaN               NaN
# 1  PyCharm;Visual Studio Code;WebStorm     MacOS;Windows
# 2                        Visual Studio           Windows
#
#   OpSysProfessional use OfficeStackAsyncHaveWorkedWith  \
# 0                   NaN                            NaN
# 1                 MacOS                            NaN
# 2               Windows                            NaN
#
#   OfficeStackAsyncWantToWorkWith OfficeStackAsyncAdmired  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
#
#                   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 0                                           NaN                           NaN
# 1                         Microsoft Teams;Slack                         Slack
# 2  Google Chat;Google Meet;Microsoft Teams;Zoom  Google Chat;Google Meet;Zoom
#
#          OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# 0                           NaN                       NaN
# 1                         Slack                       NaN
# 2  Google Chat;Google Meet;Zoom                       NaN
#
#   AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
#
#                                           NEWSOSites             SOVisitFreq  \
# 0  I have never visited Stack Overflow or the Sta...                     NaN
# 1  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
# 2  Stack Overflow;Stack Exchange;Stack Overflow B...  Multiple times per day
#
#   SOAccount              SOPartFreq  \
# 0       NaN                     NaN
# 1       Yes  Multiple times per day
# 2       Yes  Multiple times per day
#
#                                                SOHow           SOComm  \
# 0                                                NaN              NaN
# 1  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2  Quickly finding code solutions;Finding reliabl...  Yes, definitely
#
#                   AISelect          AISent                  AIBen AIAcc  \
# 0                      Yes  Very favorable  Increase productivity   NaN
# 1  No, and I don't plan to             NaN                    NaN   NaN
# 2  No, and I don't plan to             NaN                    NaN   NaN
#
#   AIComplex AIToolCurrently Using AIToolInterested in Using  \
# 0       NaN                   NaN                       NaN
# 1       NaN                   NaN                       NaN
# 2       NaN                   NaN                       NaN
#
#   AIToolNot interested in Using AINextMuch more integrated AINextNo change  \
# 0                           NaN                        NaN             NaN
# 1                           NaN                        NaN             NaN
# 2                           NaN                        NaN             NaN
#
#   AINextMore integrated AINextLess integrated AINextMuch less integrated  \
# 0                   NaN                   NaN                        NaN
# 1                   NaN                   NaN                        NaN
# 2                   NaN                   NaN                        NaN
#
#   AIThreat AIEthics AIChallenges TBranch                  ICorPM  WorkExp  \
# 0      NaN      NaN          NaN      No                     NaN      NaN
# 1      NaN      NaN          NaN     Yes  Individual contributor     17.0
# 2      NaN      NaN          NaN      No                     NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5  \
# 0         NaN         NaN         NaN         NaN         NaN
# 1       Agree    Disagree       Agree       Agree       Agree
# 2         NaN         NaN         NaN         NaN         NaN
#
#                   Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9 Frequency_1  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1  Neither agree nor disagree    Disagree       Agree       Agree         NaN
# 2                         NaN         NaN         NaN         NaN         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering Frustration  \
# 0         NaN         NaN           NaN           NaN         NaN
# 1         NaN         NaN           NaN           NaN         NaN
# 2         NaN         NaN           NaN           NaN         NaN
#
#   ProfessionalTech ProfessionalCloud ProfessionalQuestion Industry  \
# 0              NaN               NaN                  NaN      NaN
# 1              NaN               NaN                  NaN      NaN
# 2              NaN               NaN                  NaN      NaN
#
#    JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# 0             NaN             NaN             NaN             NaN
# 1             0.0             0.0             0.0             0.0
# 2             NaN             NaN             NaN             NaN
#
#    JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# 0             NaN             NaN             NaN              NaN
# 1             0.0             0.0             0.0              0.0
# 2             NaN             NaN             NaN              NaN
#
#    JobSatPoints_11           SurveyLength SurveyEase  ConvertedCompYearly  \
# 0              NaN                    NaN        NaN                  NaN
# 1              0.0                    NaN        NaN                  NaN
# 2              NaN  Appropriate in length       Easy                  NaN
#
#    JobSat
# 0     NaN
# 1     NaN
# 2     NaN

# %% [markdown]
# ### 2. Explore the Dataset
# ##### Task 1: Display basic information and summary statistics of the dataset.

# %%
df.describe(include='all')
# Out:
#           ResponseId                      MainBranch              Age  \
# count   65457.000000                           65457            65457
# unique           NaN                               5                8
# top              NaN  I am a developer by profession  25-34 years old
# freq             NaN                           50219            23913
# mean    32714.493591                             NaN              NaN
# std     18892.431636                             NaN              NaN
# min         1.000000                             NaN              NaN
# 25%     16354.000000                             NaN              NaN
# 50%     32716.000000                             NaN              NaN
# 75%     49076.000000                             NaN              NaN
# max     65437.000000                             NaN              NaN
#
#                  Employment                            RemoteWork   Check  \
# count                 65457                                 54820   65457
# unique                  110                                     3       1
# top     Employed, full-time  Hybrid (some remote, some in-person)  Apples
# freq                  39051                                 23018   65457
# mean                    NaN                                   NaN     NaN
# std                     NaN                                   NaN     NaN
# min                     NaN                                   NaN     NaN
# 25%                     NaN                                   NaN     NaN
# 50%                     NaN                                   NaN     NaN
# 75%                     NaN                                   NaN     NaN
# max                     NaN                                   NaN     NaN
#
#        CodingActivities                                       EdLevel  \
# count             54480                                         60803
# unique              118                                             8
# top               Hobby  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# freq               9995                                         24947
# mean                NaN                                           NaN
# std                 NaN                                           NaN
# min                 NaN                                           NaN
# 25%                 NaN                                           NaN
# 50%                 NaN                                           NaN
# 75%                 NaN                                           NaN
# max                 NaN                                           NaN
#
#                                                 LearnCode  \
# count                                               60507
# unique                                                418
# top     Other online resources (e.g., videos, blogs, f...
# freq                                                 3676
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                           LearnCodeOnline  \
# count                                               49251
# unique                                              10853
# top     Technical documentation;Blogs;Written Tutorial...
# freq                                                  603
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   TechDoc YearsCode  \
# count                                               40907     59887
# unique                                                113        52
# top     API document(s) and/or SDK document(s);User gu...        10
# freq                                                 6949      4562
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#        YearsCodePro                DevType             OrgSize  \
# count         51623                  59463               47488
# unique           52                     34                  10
# top               2  Developer, full-stack  20 to 99 employees
# freq           4169                  18265                9754
# mean            NaN                    NaN                 NaN
# std             NaN                    NaN                 NaN
# min             NaN                    NaN                 NaN
# 25%             NaN                    NaN                 NaN
# 50%             NaN                    NaN                 NaN
# 75%             NaN                    NaN                 NaN
# max             NaN                    NaN                 NaN
#
#             PurchaseInfluence  \
# count                   47414
# unique                      3
# top     I have some influence
# freq                    19198
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                BuyNewTool  \
# count                                               45188
# unique                                                215
# top     Start a free trial;Ask developers I know/work ...
# freq                                                 6620
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                BuildvsBuy  \
# count                                               43366
# unique                                                  3
# top     Is ready-to-go but also customizable for growt...
# freq                                                25978
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               TechEndorse  \
# count                                               43675
# unique                                                386
# top     APIs;Customization;Reputation for quality and ...
# freq                                                 1499
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                          Country           Currency      CompTotal  \
# count                      58949              46692   3.374400e+04
# unique                       185                142            NaN
# top     United States of America  EUR European Euro            NaN
# freq                       11099              12732            NaN
# mean                         NaN                NaN  2.963490e+145
# std                          NaN                NaN  5.443794e+147
# min                          NaN                NaN   0.000000e+00
# 25%                          NaN                NaN   6.000000e+04
# 50%                          NaN                NaN   1.100000e+05
# 75%                          NaN                NaN   2.500000e+05
# max                          NaN                NaN  1.000000e+150
#
#                 LanguageHaveWorkedWith LanguageWantToWorkWith LanguageAdmired  \
# count                            59763                  55769           50888
# unique                           23864                  22769           12335
# top     HTML/CSS;JavaScript;TypeScript                 Python          Python
# freq                              1004                    922            1555
# mean                               NaN                    NaN             NaN
# std                                NaN                    NaN             NaN
# min                                NaN                    NaN             NaN
# 25%                                NaN                    NaN             NaN
# 50%                                NaN                    NaN             NaN
# 75%                                NaN                    NaN             NaN
# max                                NaN                    NaN             NaN
#
#        DatabaseHaveWorkedWith DatabaseWantToWorkWith DatabaseAdmired  \
# count                   50269                  42571           38570
# unique                   9050                   8478            4051
# top                PostgreSQL             PostgreSQL      PostgreSQL
# freq                     3217                   3739            4895
# mean                      NaN                    NaN             NaN
# std                       NaN                    NaN             NaN
# min                       NaN                    NaN             NaN
# 25%                       NaN                    NaN             NaN
# 50%                       NaN                    NaN             NaN
# 75%                       NaN                    NaN             NaN
# max                       NaN                    NaN             NaN
#
#            PlatformHaveWorkedWith     PlatformWantToWorkWith  \
# count                       42378                      34543
# unique                       5467                       4784
# top     Amazon Web Services (AWS)  Amazon Web Services (AWS)
# freq                         6607                       4860
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
#                   PlatformAdmired WebframeHaveWorkedWith  \
# count                       31388                  45171
# unique                       2556                  12235
# top     Amazon Web Services (AWS)                  React
# freq                         6242                   1284
# mean                          NaN                    NaN
# std                           NaN                    NaN
# min                           NaN                    NaN
# 25%                           NaN                    NaN
# 50%                           NaN                    NaN
# 75%                           NaN                    NaN
# max                           NaN                    NaN
#
#        WebframeWantToWorkWith WebframeAdmired EmbeddedHaveWorkedWith  \
# count                   38544           34952                  22221
# unique                  11654            5460                   1630
# top                     React           React            Rasberry Pi
# freq                      997            1422                   3892
# mean                      NaN             NaN                    NaN
# std                       NaN             NaN                    NaN
# min                       NaN             NaN                    NaN
# 25%                       NaN             NaN                    NaN
# 50%                       NaN             NaN                    NaN
# 75%                       NaN             NaN                    NaN
# max                       NaN             NaN                    NaN
#
#        EmbeddedWantToWorkWith EmbeddedAdmired MiscTechHaveWorkedWith  \
# count                   17606           16739                  39450
# unique                   1471            1053                   9288
# top               Rasberry Pi     Rasberry Pi             .NET (5+)
# freq                     3038            3448                   2388
# mean                      NaN             NaN                    NaN
# std                       NaN             NaN                    NaN
# min                       NaN             NaN                    NaN
# 25%                       NaN             NaN                    NaN
# 50%                       NaN             NaN                    NaN
# 75%                       NaN             NaN                    NaN
# max                       NaN             NaN                    NaN
#
#        MiscTechWantToWorkWith MiscTechAdmired ToolsTechHaveWorkedWith  \
# count                   32969           29601                   52497
# unique                  10263            4917                   19883
# top                .NET (5+)       .NET (5+)                   Docker
# freq                     2379            3597                     949
# mean                      NaN             NaN                     NaN
# std                       NaN             NaN                     NaN
# min                       NaN             NaN                     NaN
# 25%                       NaN             NaN                     NaN
# 50%                       NaN             NaN                     NaN
# 75%                       NaN             NaN                     NaN
# max                       NaN             NaN                     NaN
#
#        ToolsTechWantToWorkWith ToolsTechAdmired NEWCollabToolsHaveWorkedWith  \
# count                    46098            44011                        57609
# unique                   16549            11804                        14168
# top                     Docker           Docker           Visual Studio Code
# freq                      1184             1583                         6159
# mean                       NaN              NaN                          NaN
# std                        NaN              NaN                          NaN
# min                        NaN              NaN                          NaN
# 25%                        NaN              NaN                          NaN
# 50%                        NaN              NaN                          NaN
# 75%                        NaN              NaN                          NaN
# max                        NaN              NaN                          NaN
#
#        NEWCollabToolsWantToWorkWith NEWCollabToolsAdmired OpSysPersonal use  \
# count                         52103                 50727             58190
# unique                         9751                  7545              2488
# top              Visual Studio Code    Visual Studio Code           Windows
# freq                           6743                  8240             11518
# mean                            NaN                   NaN               NaN
# std                             NaN                   NaN               NaN
# min                             NaN                   NaN               NaN
# 25%                             NaN                   NaN               NaN
# 50%                             NaN                   NaN               NaN
# 75%                             NaN                   NaN               NaN
# max                             NaN                   NaN               NaN
#
#        OpSysProfessional use OfficeStackAsyncHaveWorkedWith  \
# count                  52986                          48103
# unique                  2032                           6014
# top                  Windows                           Jira
# freq                   10475                           3721
# mean                     NaN                            NaN
# std                      NaN                            NaN
# min                      NaN                            NaN
# 25%                      NaN                            NaN
# 50%                      NaN                            NaN
# 75%                      NaN                            NaN
# max                      NaN                            NaN
#
#        OfficeStackAsyncWantToWorkWith OfficeStackAsyncAdmired  \
# count                           38973                   37210
# unique                           3801                    2661
# top                              Jira                    Jira
# freq                             3049                    3313
# mean                              NaN                     NaN
# std                               NaN                     NaN
# min                               NaN                     NaN
# 25%                               NaN                     NaN
# 50%                               NaN                     NaN
# 75%                               NaN                     NaN
# max                               NaN                     NaN
#
#        OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# count                          55561                         46724
# unique                          5049                          3205
# top                  Microsoft Teams               Microsoft Teams
# freq                            5764                          4326
# mean                             NaN                           NaN
# std                              NaN                           NaN
# min                              NaN                           NaN
# 25%                              NaN                           NaN
# 50%                              NaN                           NaN
# 75%                              NaN                           NaN
# max                              NaN                           NaN
#
#        OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# count                   44725                     44460
# unique                   2555                      2663
# top           Microsoft Teams                   ChatGPT
# freq                     4678                     10801
# mean                      NaN                       NaN
# std                       NaN                       NaN
# min                       NaN                       NaN
# 25%                       NaN                       NaN
# 50%                       NaN                       NaN
# 75%                       NaN                       NaN
# max                       NaN                       NaN
#
#        AISearchDevWantToWorkWith AISearchDevAdmired  \
# count                      36708              35550
# unique                      2361               1488
# top                      ChatGPT            ChatGPT
# freq                        7479              10094
# mean                         NaN                NaN
# std                          NaN                NaN
# min                          NaN                NaN
# 25%                          NaN                NaN
# 50%                          NaN                NaN
# 75%                          NaN                NaN
# max                          NaN                NaN
#
#                            NEWSOSites           SOVisitFreq SOAccount  \
# count                           60306                 59555     59579
# unique                             32                     5         3
# top     Stack Overflow;Stack Exchange  A few times per week       Yes
# freq                            30173                 19241     45467
# mean                              NaN                   NaN       NaN
# std                               NaN                   NaN       NaN
# min                               NaN                   NaN       NaN
# 25%                               NaN                   NaN       NaN
# 50%                               NaN                   NaN       NaN
# 75%                               NaN                   NaN       NaN
# max                               NaN                   NaN       NaN
#
#                                  SOPartFreq  \
# count                                 45251
# unique                                    6
# top     Less than once per month or monthly
# freq                                  24166
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                                                     SOHow          SOComm  \
# count                                               58980           59181
# unique                                                111               6
# top     Quickly finding code solutions;Finding reliabl...  No, not really
# freq                                                13547           17732
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#        AISelect     AISent                                              AIBen  \
# count     60926      45883                                              36902
# unique        3          6                                                113
# top         Yes  Favorable  Increase productivity;Greater efficiency;Speed...
# freq      37670      22171                                               4391
# mean        NaN        NaN                                                NaN
# std         NaN        NaN                                                NaN
# min         NaN        NaN                                                NaN
# 25%         NaN        NaN                                                NaN
# 50%         NaN        NaN                                                NaN
# 75%         NaN        NaN                                                NaN
# max         NaN        NaN                                                NaN
#
#                  AIAcc                                      AIComplex  \
# count            37309                                          37028
# unique               5                                              5
# top     Somewhat trust  Good, but not great at handling complex tasks
# freq             15041                                          12103
# mean               NaN                                            NaN
# std                NaN                                            NaN
# min                NaN                                            NaN
# 25%                NaN                                            NaN
# 50%                NaN                                            NaN
# 75%                NaN                                            NaN
# max                NaN                                            NaN
#
#                                     AIToolCurrently Using  \
# count                                               35079
# unique                                               1310
# top     Writing code;Debugging and getting help;Search...
# freq                                                 2024
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         AIToolInterested in Using AIToolNot interested in Using  \
# count                       30697                         24417
# unique                       1949                          1531
# top     Learning about a codebase              Project planning
# freq                          599                          1734
# mean                          NaN                           NaN
# std                           NaN                           NaN
# min                           NaN                           NaN
# 25%                           NaN                           NaN
# 50%                           NaN                           NaN
# 75%                           NaN                           NaN
# max                           NaN                           NaN
#
#        AINextMuch more integrated AINextNo change AINextMore integrated  \
# count                       13439           12502                 24431
# unique                        700             539                   884
# top            Search for answers    Writing code          Writing code
# freq                         1426            1853                  2608
# mean                          NaN             NaN                   NaN
# std                           NaN             NaN                   NaN
# min                           NaN             NaN                   NaN
# 25%                           NaN             NaN                   NaN
# 50%                           NaN             NaN                   NaN
# 75%                           NaN             NaN                   NaN
# max                           NaN             NaN                   NaN
#
#        AINextLess integrated AINextMuch less integrated AIThreat  \
# count                   2355                       1148    44698
# unique                   249                        286        3
# top             Writing code               Writing code       No
# freq                     490                        154    30429
# mean                     NaN                        NaN      NaN
# std                      NaN                        NaN      NaN
# min                      NaN                        NaN      NaN
# 25%                      NaN                        NaN      NaN
# 50%                      NaN                        NaN      NaN
# 75%                      NaN                        NaN      NaN
# max                      NaN                        NaN      NaN
#
#                                                  AIEthics  \
# count                                               41556
# unique                                                126
# top     Circulating misinformation or disinformation;M...
# freq                                                 2998
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                              AIChallenges TBranch  \
# count                                               37536   44490
# unique                                                232       2
# top     Don’t trust the output or answers;AI tools lac...     Yes
# freq                                                 5505   29966
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#                         ICorPM       WorkExp Knowledge_1 Knowledge_2  \
# count                    29807  29664.000000       28669       28026
# unique                       2           NaN           5           5
# top     Individual contributor           NaN       Agree       Agree
# freq                     25893           NaN       13456        9061
# mean                       NaN     11.466323         NaN         NaN
# std                        NaN      9.168205         NaN         NaN
# min                        NaN      0.000000         NaN         NaN
# 25%                        NaN      4.000000         NaN         NaN
# 50%                        NaN      9.000000         NaN         NaN
# 75%                        NaN     16.000000         NaN         NaN
# max                        NaN     50.000000         NaN         NaN
#
#        Knowledge_3 Knowledge_4 Knowledge_5 Knowledge_6 Knowledge_7  \
# count        28100       28035       27885       27869       27783
# unique           5           5           5           5           5
# top          Agree       Agree       Agree       Agree       Agree
# freq         10981       12513       14615        9936       10281
# mean           NaN         NaN         NaN         NaN         NaN
# std            NaN         NaN         NaN         NaN         NaN
# min            NaN         NaN         NaN         NaN         NaN
# 25%            NaN         NaN         NaN         NaN         NaN
# 50%            NaN         NaN         NaN         NaN         NaN
# 75%            NaN         NaN         NaN         NaN         NaN
# max            NaN         NaN         NaN         NaN         NaN
#
#        Knowledge_8 Knowledge_9       Frequency_1       Frequency_2  \
# count        27763       27640             28374             28369
# unique           5           5                 5                 5
# top          Agree       Agree  1-2 times a week  1-2 times a week
# freq         10762        6659             16992             12580
# mean           NaN         NaN               NaN               NaN
# std            NaN         NaN               NaN               NaN
# min            NaN         NaN               NaN               NaN
# 25%            NaN         NaN               NaN               NaN
# 50%            NaN         NaN               NaN               NaN
# 75%            NaN         NaN               NaN               NaN
# max            NaN         NaN               NaN               NaN
#
#              Frequency_3        TimeSearching        TimeAnswering  \
# count              27715                28916                28849
# unique                 5                    5                    5
# top     1-2 times a week  30-60 minutes a day  15-30 minutes a day
# freq               14428                10954                 9341
# mean                 NaN                  NaN                  NaN
# std                  NaN                  NaN                  NaN
# min                  NaN                  NaN                  NaN
# 25%                  NaN                  NaN                  NaN
# 50%                  NaN                  NaN                  NaN
# 75%                  NaN                  NaN                  NaN
# max                  NaN                  NaN                  NaN
#
#           Frustration ProfessionalTech           ProfessionalCloud  \
# count           28255            27768                       28496
# unique            954              514                           3
# top     None of these    None of these  Hybrid (on-prem and cloud)
# freq             2364             2835                       13231
# mean              NaN              NaN                         NaN
# std               NaN              NaN                         NaN
# min               NaN              NaN                         NaN
# 25%               NaN              NaN                         NaN
# 50%               NaN              NaN                         NaN
# 75%               NaN              NaN                         NaN
# max               NaN              NaN                         NaN
#
#                     ProfessionalQuestion              Industry  \
# count                              28812                 28863
# unique                                 9                    15
# top     Traditional public search engine  Software Development
# freq                               15815                 11919
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# count     29330.000000    29399.000000    29417.000000    29456.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean         18.578998        7.520604       10.059485       24.339971
# std          25.965347       18.421094       21.831924       27.088870
# min           0.000000        0.000000        0.000000        0.000000
# 25%           0.000000        0.000000        0.000000        0.000000
# 50%          10.000000        0.000000        0.000000       20.000000
# 75%          22.000000        5.000000       10.000000       30.000000
# max         100.000000      100.000000      100.000000      100.000000
#
#         JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# count     29454.000000    29462.000000    29462.000000     29456.000000
# unique             NaN             NaN             NaN              NaN
# top                NaN             NaN             NaN              NaN
# freq               NaN             NaN             NaN              NaN
# mean         22.964277       20.279127       16.167837        10.953481
# std          27.017634       26.110706       24.844177        22.904463
# min           0.000000        0.000000        0.000000         0.000000
# 25%           0.000000        0.000000        0.000000         0.000000
# 50%          15.000000       10.000000        5.000000         0.000000
# 75%          30.000000       25.000000       20.000000        10.000000
# max         100.000000      100.000000      100.000000       100.000000
#
#         JobSatPoints_11           SurveyLength SurveyEase  \
# count      29451.000000                  56198      56255
# unique              NaN                      3          3
# top                 NaN  Appropriate in length       Easy
# freq                NaN                  38778      30081
# mean           9.953618                    NaN        NaN
# std           21.775070                    NaN        NaN
# min            0.000000                    NaN        NaN
# 25%            0.000000                    NaN        NaN
# 50%            0.000000                    NaN        NaN
# 75%           10.000000                    NaN        NaN
# max          100.000000                    NaN        NaN
#
#         ConvertedCompYearly        JobSat
# count          2.343700e+04  29131.000000
# unique                  NaN           NaN
# top                     NaN           NaN
# freq                    NaN           NaN
# mean           8.615893e+04      6.934915
# std            1.867532e+05      2.088356
# min            1.000000e+00      0.000000
# 25%            3.271200e+04      6.000000
# 50%            6.500000e+04      7.000000
# 75%            1.080000e+05      8.000000
# max            1.625660e+07     10.000000

# %% [markdown]
# ### 3. Finding Missing Values
# ##### Task 2: Identify missing values for all columns.

# %%
# 1. Identifying missing values
missing=df.isna()

# %%
missing_stats=missing.sum().sort_values(ascending=False).to_frame(name='count')
missing_stats['Missing (%)'] = (missing_stats['count'] / len(df) * 100).round(3)
missing_stats
# Out:
#                                 count  Missing (%)
# AINextMuch less integrated      64309       98.246
# AINextLess integrated           63102       96.402
# AINextNo change                 52955       80.900
# AINextMuch more integrated      52018       79.469
# EmbeddedAdmired                 48718       74.427
# EmbeddedWantToWorkWith          47851       73.103
# EmbeddedHaveWorkedWith          43236       66.053
# ConvertedCompYearly             42020       64.195
# AIToolNot interested in Using   41040       62.698
# AINextMore integrated           41026       62.676
# Knowledge_9                     37817       57.774
# Frequency_3                     37742       57.659
# Knowledge_8                     37694       57.586
# ProfessionalTech                37689       57.578
# Knowledge_7                     37674       57.555
# Knowledge_6                     37588       57.424
# Knowledge_5                     37572       57.400
# Knowledge_2                     37431       57.184
# Knowledge_4                     37422       57.170
# Knowledge_3                     37357       57.071
# Frustration                     37202       56.834
# Frequency_2                     37088       56.660
# Frequency_1                     37083       56.652
# ProfessionalCloud               36961       56.466
# Knowledge_1                     36788       56.202
# ProfessionalQuestion            36645       55.983
# TimeAnswering                   36608       55.927
# Industry                        36594       55.905
# TimeSearching                   36541       55.824
# JobSat                          36326       55.496
# JobSatPoints_1                  36127       55.192
# JobSatPoints_4                  36058       55.087
# JobSatPoints_5                  36040       55.059
# JobSatPoints_11                 36006       55.007
# JobSatPoints_7                  36003       55.003
# JobSatPoints_6                  36001       54.999
# JobSatPoints_10                 36001       54.999
# JobSatPoints_8                  35995       54.990
# JobSatPoints_9                  35995       54.990
# MiscTechAdmired                 35856       54.778
# WorkExp                         35793       54.682
# ICorPM                          35650       54.463
# AIToolInterested in Using       34760       53.104
# PlatformAdmired                 34069       52.048
# MiscTechWantToWorkWith          32488       49.633
# CompTotal                       31713       48.449
# PlatformWantToWorkWith          30914       47.228
# WebframeAdmired                 30505       46.603
# AIToolCurrently Using           30378       46.409
# AISearchDevAdmired              29907       45.690
# AISearchDevWantToWorkWith       28749       43.920
# AIBen                           28555       43.624
# AIComplex                       28429       43.432
# OfficeStackAsyncAdmired         28247       43.154
# AIAcc                           28148       43.002
# AIChallenges                    27921       42.655
# WebframeWantToWorkWith          26913       41.116
# DatabaseAdmired                 26887       41.076
# OfficeStackAsyncWantToWorkWith  26484       40.460
# MiscTechHaveWorkedWith          26007       39.731
# TechDoc                         24550       37.506
# AIEthics                        23901       36.514
# PlatformHaveWorkedWith          23079       35.258
# DatabaseWantToWorkWith          22886       34.963
# BuildvsBuy                      22091       33.749
# TechEndorse                     21782       33.277
# ToolsTechAdmired                21446       32.763
# AISearchDevHaveWorkedWith       20997       32.078
# TBranch                         20967       32.032
# AIThreat                        20759       31.714
# OfficeStackSyncAdmired          20732       31.673
# WebframeHaveWorkedWith          20286       30.991
# BuyNewTool                      20269       30.965
# SOPartFreq                      20206       30.869
# AISent                          19574       29.904
# ToolsTechWantToWorkWith         19359       29.575
# Currency                        18765       28.668
# OfficeStackSyncWantToWorkWith   18733       28.619
# PurchaseInfluence               18043       27.565
# OrgSize                         17969       27.452
# OfficeStackAsyncHaveWorkedWith  17354       26.512
# LearnCodeOnline                 16206       24.758
# DatabaseHaveWorkedWith          15188       23.203
# NEWCollabToolsAdmired           14730       22.503
# LanguageAdmired                 14569       22.257
# YearsCodePro                    13834       21.134
# NEWCollabToolsWantToWorkWith    13354       20.401
# ToolsTechHaveWorkedWith         12960       19.799
# OpSysProfessional use           12471       19.052
# CodingActivities                10977       16.770
# RemoteWork                      10637       16.250
# OfficeStackSyncHaveWorkedWith    9896       15.118
# LanguageWantToWorkWith           9688       14.801
# SurveyLength                     9259       14.145
# SurveyEase                       9202       14.058
# NEWCollabToolsHaveWorkedWith     7848       11.990
# OpSysPersonal use                7267       11.102
# Country                          6508        9.942
# SOHow                            6477        9.895
# SOComm                           6276        9.588
# DevType                          5994        9.157
# SOVisitFreq                      5902        9.017
# SOAccount                        5878        8.980
# LanguageHaveWorkedWith           5694        8.699
# YearsCode                        5570        8.509
# NEWSOSites                       5151        7.869
# LearnCode                        4950        7.562
# EdLevel                          4654        7.110
# AISelect                         4531        6.922
# MainBranch                          0        0.000
# Age                                 0        0.000
# Employment                          0        0.000
# Check                               0        0.000
# ResponseId                          0        0.000

# %% [markdown]
# ##### Task 3: Visualize missing values using a heatmap (Using seaborn library).

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=missing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.figure(figsize=(10,8))
#       2 sns.heatmap(data=missing)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Task 4: Count the number of missing rows for a specific column (e.g., `Employment`).

# %%
## Write your code here

# %% [markdown]
# ### 4. Imputing Missing Values
# ##### Task 5: Identify the most frequent (majority) value in a specific column (e.g., `Employment`).

# %%
## Write your code here

# %% [markdown]
# ##### Task 6: Impute missing values in the `Employment` column with the most frequent value.

# %%
## Write your code here

# %% [markdown]
# ### 5. Visualizing Imputed Data
# ##### Task 7: Visualize the distribution of a column after imputation (e.g., `Employment`).

# %%
## Write your code here

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you:
# - Loaded the dataset into a pandas DataFrame.
# - Identified missing values across all columns.
# - Quantified missing values in specific columns.
# - Imputed missing values in a categorical column using the most frequent value.
# - Visualized the imputed data for better understanding.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
